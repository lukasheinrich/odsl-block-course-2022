# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import jax

size = np.linspace(0,1)
cls = np.linspace(0,1,11)
powers = np.array([size/c for c in cls])
plt.plot(size,powers.T);
plt.xlim(0,1)
plt.ylim(0,1)
plt.gcf().set_size_inches(5,5)
